# %% [markdown]
# # Counterfactual Experiment Analysis
#
# This notebook runs the counterfactual method comparison analysis, producing the main vs baseline bar chart.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd().parent.parent))

from scripts.counterfactual_experiment.analyze import run_analysis

# %%
# Configure paths - adjust to your setup
input_dir = Path("results/counterfactual/identical/esm3")  # directory with evaluate output CSVs
output_dir = Path("results/counterfactual/identical/esm3/analysis")

run_analysis(input_dir=input_dir, output_dir=output_dir, sort_by="prediction_change")
